# %%
import pandas as pd
import numpy as np

# %%
# must have keep_default_na false to prevent conversion of None str into NA when importing
df_raw = pd.read_csv('./opendata/samhsa_sud/teds_d/derived/teds-d_15-21-clean.csv', keep_default_na=False)

# %%
df_raw.shape
# Out:
# (10671578, 70)

# %%
# sanity check
df_raw.isna().sum().sort_values(ascending=False)
# Out:
# CASEID                 0
# IDU                    0
# OPSYNFLG               0
# METHFLG                0
# HERFLG                 0
#                       ..
# FREQ1                  0
# FREQ1_D                0
# FRSTUSE1               0
# SUB2                   0
# FREQ_ATND_SELF_HELP    0
# Length: 70, dtype: int64

# %%
df_raw.head()
# Out:
#         CASEID  DISYR              AGE  GENDER  \
# 0  20151281720   2015  25-29 years old    Male
# 1  20151201902   2015  55-64 years old  Female
# 2  20151182461   2015  40-44 years old  Female
# 3  20151151190   2015  21-24 years old  Female
# 4  20151214753   2015  25-29 years old  Female
#
#                                      RACE                            ETHNIC  \
# 0                                   White  Not of Hispanic or Latino origin
# 1  Alaska Native (Aleut, Eskimo, Indian))  Not of Hispanic or Latino origin
# 2  Alaska Native (Aleut, Eskimo, Indian))  Not of Hispanic or Latino origin
# 3                                   White  Not of Hispanic or Latino origin
# 4                       Two or more races  Not of Hispanic or Latino origin
#
#              MARSTAT                                   EDUC  \
# 0      Never married                      Grade 12 (or GED)
# 1  Divorced, Widowed  Missing/unknown/not collected/invalid
# ...

# %%
df_raw.GENDER.value_counts()
# Out:
# GENDER
# Male                                     6914694
# Female                                   3752831
# Missing/unknown/not collected/invalid       4053
# Name: count, dtype: int64

# %%
df_raw.RACE.value_counts()
# Out:
# RACE
# White                                         7050699
# Black or African American                     1829853
# Other single race                              833557
# Missing/unknown/not collected/invalid          310085
# American Indian (other than Alaska Native)     265092
# Two or more races                              226935
# Asian                                           68759
# Native Hawaiian or Other Pacific Islander       56910
# Alaska Native (Aleut, Eskimo, Indian))          22033
# Asian or Pacific Islander                        4629
# Alaska Native (Aleut, Eskimo, Indian)            3026
# Name: count, dtype: int64

# %%
df_raw.ETHNIC.value_counts()
# Out:
# ETHNIC
# Not of Hispanic or Latino origin                     8906087
# Mexican                                               459076
# Puerto Rican                                          381842
# Cuban or other specific Hispanic                      330129
# Missing/unknown/not collected/invalid                 322431
# Hispanic or Latino, specific origin not specified     272013
# Name: count, dtype: int64

# %%
df_raw.AGE.value_counts()
# Out:
# AGE
# 25-29 years old       1826183
# 30-34 years old       1817649
# 35-39 years old       1469366
# 40-44 years old       1060875
# 45-49 years old        942014
# 21-24 years old        937197
# 55-64 years old        936541
# 50-54 years old        873608
# 18-20 years old        335537
# 15-17 years old        280040
# 65 years and older     134921
# 12-14 years old         57647
# Name: count, dtype: int64
